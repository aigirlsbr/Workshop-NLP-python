# %% [markdown]
# # Introdução ao Processamento de Linguagem Natural usando Python

# %% [markdown]
# # Antes de começar!
#
# ### Dicas!
#
# Para instalar novos pacotes:
#
#  - pip install nome_do_pacote
#
# OU
#
#  - conda install nome_do_pacote
#
#
# ### Pacotes necessarios:
#     - conda install -c conda-forge wordcloud
#     - pip install nltk
#     - pip install pandas
#     - pip install spacy

# %% [markdown]
# ## Atenção!
#
# Os nomes das lojas foram ocultados para mantermos a segurança da loja.
#
# A empresa foi substituído por códigos para representar cada uma individualmente.
#
# Dentro do corpo da reclamação, o nome da loja foi substituído  por "LOJA"
#
# Nomes e emails também foram removidos.

# %% [markdown]
# # Atenção!
#
# Antes de começarmos é necessario baixar a lista de stopwords, sentence tokenization e o corpus do NLTK

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('machado')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\gabriel\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\gabriel\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package machado to
# [nltk_data]     C:\Users\gabriel\AppData\Roaming\nltk_data...
# [nltk_data]   Package machado is already up-to-date!
# True

# %% [markdown]
# # 1. Exemplo -  Corpus

# %%
from nltk.corpus import machado

# Verificando o conjunto de textos contido no Corpus Machado
print(machado.fileids())

# Cada arquivo corresponde a uma das obras de Machado de Assis.
# Out:
# ['contos/macn001.txt', 'contos/macn002.txt', 'contos/macn003.txt', 'contos/macn004.txt', 'contos/macn005.txt', 'contos/macn006.txt', 'contos/macn007.txt', 'contos/macn008.txt', 'contos/macn009.txt', 'contos/macn010.txt', 'contos/macn011.txt', 'contos/macn012.txt', 'contos/macn013.txt', 'contos/macn014.txt', 'contos/macn015.txt', 'contos/macn016.txt', 'contos/macn017.txt', 'contos/macn018.txt', 'contos/macn019.txt', 'contos/macn020.txt', 'contos/macn021.txt', 'contos/macn022.txt', 'contos/macn023.txt', 'contos/macn024.txt', 'contos/macn025.txt', 'contos/macn026.txt', 'contos/macn027.txt', 'contos/macn028.txt', 'contos/macn029.txt', 'contos/macn030.txt', 'contos/macn031.txt', 'contos/macn032.txt', 'contos/macn033.txt', 'contos/macn034.txt', 'contos/macn035.txt', 'contos/macn036.txt', 'contos/macn037.txt', 'contos/macn038.txt', 'contos/macn039.txt', 'contos/macn040.txt', 'contos/macn041.txt', 'contos/macn042.txt', 'contos/macn043.txt', 'contos/macn044.txt', 'contos/macn045.txt', 'contos/macn046.txt', 'contos/macn047.txt', 'contos/macn048.txt', 'contos/macn049.txt', 'contos/macn050.txt', 'contos/macn051.txt', 'contos/macn052.txt', 'contos/macn053.txt', 'contos/macn054.txt', 'contos/macn055.txt', 'contos/macn056.txt', 'contos/macn057.txt', 'contos/macn058.txt', 'contos/macn059.txt', 'contos/macn060.txt', 'contos/macn061.txt', 'contos/macn062.txt', 'contos/macn063.txt', 'contos/macn064.txt', 'contos/macn065.txt', 'contos/macn066.txt', 'contos/macn067.txt', 'contos/macn068.txt', 'contos/macn069.txt', 'contos/macn070.txt', 'contos/macn071.txt', 'contos/macn072.txt', 'contos/macn073.txt', 'contos/macn074.txt', 'contos/macn075.txt', 'contos/macn076.txt', 'contos/macn077.txt', 'contos/macn078.txt', 'contos/macn079.txt', 'contos/macn080.txt', 'contos/macn081.txt', 'contos/macn082.txt', 'contos/macn083.txt', 'contos/macn084.txt', 'contos/macn085.txt', 'contos/macn086.txt', 'contos/macn087.txt', 'contos/macn088.txt', 'contos/macn089.txt', 'contos/macn090.txt', 'contos/macn091.txt', 'contos/macn092.txt', 'contos/macn093.txt', 'contos/macn094.txt', 'contos/macn095.txt', 'contos/macn096.txt', 'contos/macn097.txt', 'contos/macn098.txt', 'contos/macn099.txt', 'contos/macn100.txt', 'contos/macn101.txt', 'contos/macn102.txt', 'contos/macn103.txt', 'contos/macn104.txt', 'contos/macn105.txt', 'contos/macn106.txt', 'contos/macn107.txt', 'contos/macn108.txt', 'contos/macn109.txt', 'contos/macn110.txt', 'contos/macn111.txt', 'contos/macn112.txt', 'contos/macn113.txt', 'contos/macn114.txt', 'contos/macn115.txt', 'contos/macn116.txt', 'contos/macn117.txt', 'contos/macn118.txt', 'contos/macn119.txt', 'contos/macn120.txt', 'contos/macn121.txt', 'contos/macn122.txt', 'contos/macn123.txt', 'contos/macn124.txt', 'contos/macn125.txt', 'contos/macn126.txt', 'contos/macn127.txt', 'contos/macn128.txt', 'contos/macn129.txt', 'contos/macn130.txt', 'contos/macn131.txt', 'contos/macn132.txt', 'contos/macn133.txt', 'contos/macn134.txt', 'contos/macn135.txt', 'contos/macn136.txt', 'contos/macn137.txt', 'critica/mact01.txt', 'critica/mact02.txt', 'critica/mact03.txt', 'critica/mact04.txt', 'critica/mact05.txt', 'critica/mact06.txt', 'critica/mact07.txt', 'critica/mact08.txt', 'critica/mact09.txt', 'critica/mact10.txt', 'critica/mact11.txt', 'critica/mact12.txt', 'critica/mact13.txt', 'critica/mact14.txt', 'critica/mact15.txt', 'critica/mact16.txt', 'critica/mact17.txt', 'critica/mact18.txt', 'critica/mact19.txt', 'critica/mact20.txt', 'critica/mact21.txt', 'critica/mact22.txt', 'critica/mact23.txt', 'critica/mact24.txt', 'critica/mact25.txt', 'critica/mact26.txt', 'critica/mact27.txt', 'critica/mact28.txt', 'critica/mact29.txt', 'critica/mact30.txt', 'critica/mact31.txt', 'critica/mact32.txt', 'critica/mact33.txt', 'critica/mact34.txt', 'critica/mact35.txt', 'critica/mact36.txt', 'critica/mact37.txt', 'critica/mact38.txt', 'critica/mact39.txt', 'critica/mact40.txt', 'critica/mact41.txt', 'critica/mact42.txt', 'critica/mact43.txt', 'critica/mact44.txt', 'critica/mact45.t ...

# %%
# Para acessar o texto como uma lista de 200 caracteres..
raw_machado_text = machado.raw('romance/marm05.txt') # explore outros arquivos
raw_machado_text[10000:10200]
# Out:
# ', primou no\nEstado, e foi um dos amigos particulares do vice-rei Conde da Cunha.\n\nComo este apelido de Cubas lhe\ncheirasse excessivamente a tanoaria, alegava meu pai, bisneto de Damião, que o\ndito ape'

# %%
# Porem, a forma acima não é uma maneira muito útil de trabalhar com um texto. 
# Geralmente pensamos em um texto como uma sequência de palavras e pontuação, não em caracteres..
text1 = machado.words('romance/marm05.txt')
text1
# Out:
# ['Romance', ',', 'Memórias', 'Póstumas', 'de', 'Brás', ...]

# %%
# Checando o tamanho do romance marm05.txt
print('Quantidade de palavras {}'.format(len(text1)))
# Checando o tamanho de palavras unicas do texto
print('Quantidade de palavras unicas {}'.format(len(set(text1))))
# Out:
# Quantidade de palavras 77098
# Quantidade de palavras unicas 10848

# %%
# Sua vez: O que mais podemos fazer?
# Liste aqui suas ideia!

# %% [markdown]
# http://www.nltk.org/howto/portuguese_en.html

# %% [markdown]
# # Dados Reclame Aqui

# %% [markdown]
# ## 1. Importando os Dados

# %% [markdown]
# ### Para executar na sua maquina local

# %%
# Descomente essa celula

# # Importando Pandas
# import pandas as pd

# # Vamos agora importar os dados que vamos trabalhar!
# reclamacoes = pd.read_csv('reclamacoes.csv', sep=';')

# print(reclamacoes.shape)

# reclamacoes.head()
# Out:
# (28, 7)
#   empresa     data_reclamacao                      local  \
# 0  Loja A   23/03/19 às 18h33             Guarulhos - SP
# 1  Loja A   23/03/19 às 18h20               Taubaté - SP
# 2  Loja A   23/03/19 às 11h07       Franco da Rocha - SP
# 3  Loja A   23/03/19 às 10h57              Teresina - PI
# 4  Loja A   22/03/19 às 19h49   São Gonçalo do Pará - MG
#
#                                    titulo_reclamacao  \
# 0                                    Mau Atendimento
# 1  Produtos misturado na gondula e divergência na...
# 2                     Informaçao errada do vendedor.
# 3              Paguei por um produto fora do estoque
# 4  entregaram meu pedido a outra pessoa falando q...
#
#                                     corpo_reclamacao  \
# 0  Nunca mais compro nessa loja pelo fato de que ...
# 1  Eu a LOJA comprar uma luva de musculação, na q...
# 2  Estive na LOJA da Marginal Tiete no dia 15 de ...
# 3  Comprei 3 produtos no dia 13.03 e recebi email...
# 4  comprei um tenis esportivo e ao receber o avis...
#
#                                                 tags  teve_resposta
# 0                                Calçados Esportivos              0
# 1  Divergência de valores, Acessórios para Muscul...              0
# 2  Produto errado, Raquetes e Tacos, Artigos Espo...              0
# 3                            Acessórios de Vestuário              1
# 4  Problemas na finalização da compra Tênis Calça...              0

# %% [markdown]
# ### Para executar no Google Colab

# %%
## Para executar no Google Colab

from google.colab import files

uploaded = files.upload()

import io
data = io.BytesIO(uploaded['reclamacoes.csv'])    

import pandas as pd   
reclamacoes = pd.read_csv(data, sep=';')

reclamacoes.head()
# Out:
#      <input type="file" id="files-a2e6cbc8-b374-4a76-92da-6bb0920e78ab" name="files[]" multiple disabled />
#      <output id="result-a2e6cbc8-b374-4a76-92da-6bb0920e78ab">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-0c5017a6c308> in <module>()
#       5
#       6 import io
# ----> 7 data = io.BytesIO(uploaded['reclamacoes.csv'])
#       8
#       9 import pandas as pd
#
# KeyError: 'reclamacoes.csv'

# %%
# Verificando se tem dados faltantes
reclamacoes.isna().sum()
# Out:
# empresa              0
# data_reclamacao      0
# local                0
# titulo_reclamacao    0
# corpo_reclamacao     0
# tags                 1
# teve_resposta        0
# dtype: int64

# %% [markdown]
# ## 2.Pré-Processamento

# %% [markdown]
# ### 2.1 Quebrando a coluna data_reclamacao em dia e hora

# %%
# Vamos separar as informações

print('Como era antes:')
print(reclamacoes['data_reclamacao'][:3])

# Separando...
reclamacoes['data'] = reclamacoes['data_reclamacao'].str.split('às',expand=True)[0]

print('\n')
print('Como ficou agora:')
print(reclamacoes['data'][:3])
# Out:
# Como era antes:
# 0     23/03/19 às 18h33
# 1     23/03/19 às 18h20
# 2     23/03/19 às 11h07
# Name: data_reclamacao, dtype: object
#
#
# Como ficou agora:
# 0     23/03/19
# 1     23/03/19
# 2     23/03/19
# Name: data, dtype: object

# %%
# Sua vez: Faça a mesma coisa para a informação hora
reclamacoes['hora'] = reclamacoes['data_reclamacao'].str.split('às',expand=True)[1]

# Você consegue identificar algo que está faltando ao utilizar essa nossa técnica?
# Dica: Utilize reclamacoes.data[0]
reclamacoes.data[0]
# Out:
# ' 23/03/19 '

# %%
# Como resolver o problema acima?
# Sua solução:
reclamacoes['data'] = reclamacoes['data'].str.strip()
reclamacoes['hora'] = reclamacoes['hora'].str.strip()

# Verifique se a sua solução funcionou:
reclamacoes.data[0]
# Out:
# '23/03/19'

# %% [markdown]
# ### 2.2 Quebrando a coluna local em Cidade e Estado

# %%
# Sua vez: Faça a mesma coisa para que você fez acima para a variavel local e estado
# não se esqueça do problema que resolvemos acima!
reclamacoes['cidade'] = reclamacoes['local'].str.split('-',expand=True)[0].str.strip()
reclamacoes['estado'] = reclamacoes['local'].str.split('-',expand=True)[1].str.strip()

# %%
# Visualizando as alterações que fizemos
reclamacoes[['data_reclamacao', 'data', 'hora', 'local', 'cidade', 'estado']].head()
# Out:
#       data_reclamacao      data   hora                      local  \
# 0   23/03/19 às 18h33  23/03/19  18h33             Guarulhos - SP
# 1   23/03/19 às 18h20  23/03/19  18h20               Taubaté - SP
# 2   23/03/19 às 11h07  23/03/19  11h07       Franco da Rocha - SP
# 3   23/03/19 às 10h57  23/03/19  10h57              Teresina - PI
# 4   22/03/19 às 19h49  22/03/19  19h49   São Gonçalo do Pará - MG
#
#                 cidade estado
# 0            Guarulhos     SP
# 1              Taubaté     SP
# 2      Franco da Rocha     SP
# 3             Teresina     PI
# 4  São Gonçalo do Pará     MG

# %% [markdown]
# ### 2.3 Alterar tipo de colunas

# %%
# Verificando o tipo de dados 
reclamacoes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 11 columns):
# empresa              28 non-null object
# data_reclamacao      28 non-null object
# local                28 non-null object
# titulo_reclamacao    28 non-null object
# corpo_reclamacao     28 non-null object
# tags                 27 non-null object
# teve_resposta        28 non-null int64
# data                 28 non-null object
# hora                 28 non-null object
# cidade               28 non-null object
# estado               28 non-null object
# dtypes: int64(1), object(10)
# memory usage: 2.5+ KB

# %%
# Colunas que são categoricas
reclamacoes['teve_resposta'] = reclamacoes['teve_resposta'].astype('category')

# Colunas que são datetime
reclamacoes['data'] = pd.to_datetime(reclamacoes['data'])

reclamacoes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 11 columns):
# empresa              28 non-null object
# data_reclamacao      28 non-null object
# local                28 non-null object
# titulo_reclamacao    28 non-null object
# corpo_reclamacao     28 non-null object
# tags                 27 non-null object
# teve_resposta        28 non-null category
# data                 28 non-null datetime64[ns]
# hora                 28 non-null object
# cidade               28 non-null object
# estado               28 non-null object
# dtypes: category(1), datetime64[ns](1), object(9)
# memory usage: 2.4+ KB

# %% [markdown]
# ### 2.4 LowerCase

# %%
print('Antes:')
print(reclamacoes['corpo_reclamacao'].head())
# Out:
# Antes:
# 0    Nunca mais compro nessa loja pelo fato de que ...
# 1    Eu a LOJA comprar uma luva de musculação, na q...
# 2    Estive na LOJA da Marginal Tiete no dia 15 de ...
# 3    Comprei 3 produtos no dia 13.03 e recebi email...
# 4    comprei um tenis esportivo e ao receber o avis...
# Name: corpo_reclamacao, dtype: object

# %%
# Aplicando Lower Case
reclamacoes['corpo_reclamacao_lower'] = [str(token).lower() for token in reclamacoes['corpo_reclamacao']]

print('Depois:')
reclamacoes.corpo_reclamacao_lower.head()
# Out:
# Depois:
# 0    nunca mais compro nessa loja pelo fato de que ...
# 1    eu a loja comprar uma luva de musculação, na q...
# 2    estive na loja da marginal tiete no dia 15 de ...
# 3    comprei 3 produtos no dia 13.03 e recebi email...
# 4    comprei um tenis esportivo e ao receber o avis...
# Name: corpo_reclamacao_lower, dtype: object

# %% [markdown]
# ### 2.5 Tokenização

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# Vamos dividir um exemplo texto em tokens/palavras:
tokens = word_tokenize('A história do NLP começou na década de 1950, com Alan Turing'.lower())

print(tokens)

print('\nQuantidade de Tokens: {}'.format(len(tokens)))
# Out:
# ['a', 'história', 'do', 'nlp', 'começou', 'na', 'década', 'de', '1950', ',', 'com', 'alan', 'turing']
#
# Quantidade de Tokens: 13

# %%
# Agora vamos dividir um exemplo texto em sentenças:
sentencas = sent_tokenize('O Processamento! de Linguagem Natural (PLN) é a subárea da Inteligência Artificial (IA) que estuda a capacidade e as limitações de uma máquina em entender a linguagem dos seres humanos. O objetivo do PLN é fornecer aos computadores a capacidade de entender e compor textos. “Entender” um texto significa reconhecer o contexto, fazer análise sintática, semântica, léxica e morfológica, criar resumos, extrair informação, interpretar os sentidos, analisar sentimentos e até aprender conceitos com os textos processados.') 

# Visualizando cada sentença
print(sentencas[0])
print()
print(sentencas[1])
print()
print(sentencas[2])

print('\nQuantidade de Sentenças: {}'.format(len(sentencas)))
# Out:
# O Processamento!
#
# de Linguagem Natural (PLN) é a subárea da Inteligência Artificial (IA) que estuda a capacidade e as limitações de uma máquina em entender a linguagem dos seres humanos.
#
# O objetivo do PLN é fornecer aos computadores a capacidade de entender e compor textos.
#
# Quantidade de Sentenças: 4

# %%
# Sua vez: Separe os nossos textos em tokens e coloque em uma nova coluna chamada corpo_reclamacao_tokens
reclamacoes['corpo_reclamacao_tokens'] = [word_tokenize(token) for token in reclamacoes['corpo_reclamacao_lower']]

# %%
# Como ficou nosso dataset até agora
reclamacoes.head()
# Out:
#   empresa     data_reclamacao                      local  \
# 0  Loja A   23/03/19 às 18h33             Guarulhos - SP
# 1  Loja A   23/03/19 às 18h20               Taubaté - SP
# 2  Loja A   23/03/19 às 11h07       Franco da Rocha - SP
# 3  Loja A   23/03/19 às 10h57              Teresina - PI
# 4  Loja A   22/03/19 às 19h49   São Gonçalo do Pará - MG
#
#                                    titulo_reclamacao  \
# 0                                    Mau Atendimento
# 1  Produtos misturado na gondula e divergência na...
# 2                     Informaçao errada do vendedor.
# 3              Paguei por um produto fora do estoque
# 4  entregaram meu pedido a outra pessoa falando q...
#
#                                     corpo_reclamacao  \
# 0  Nunca mais compro nessa loja pelo fato de que ...
# 1  Eu a LOJA comprar uma luva de musculação, na q...
# 2  Estive na LOJA da Marginal Tiete no dia 15 de ...
# 3  Comprei 3 produtos no dia 13.03 e recebi email...
# 4  comprei um tenis esportivo e ao receber o avis...
#
#                                                 tags teve_resposta       data  \
# 0                                Calçados Esportivos             0 2019-03-23
# 1  Divergência de valores, Acessórios para Muscul...             0 2019-03-23
# 2  Produto errado, Raquetes e Tacos, Artigos Espo...             0 2019-03-23
# 3                            Acessórios de Vestuário             1 2019-03-23
# 4  Problemas na finalização da compra Tênis Calça...             0 2019-03-22
#
#     hora               cidade estado  \
# 0  18h33            Guarulhos     SP
# 1  18h20              Taubaté     SP
# 2  11h07      Franco da Rocha     SP
# 3  10h57             Teresina     PI
# 4  19h49  São Gonçalo do Pará     MG
#
#                               corpo_reclamacao_lower  \
# 0  nunca mais compro nessa loja pelo fato de que ...
# 1  eu a loja comprar uma luva de musculação, na q...
# 2  estive na loja da marginal tiete no dia 15 de ...
# 3  comprei 3 produtos no dia 13.03 e recebi email...
# 4  comprei um tenis esportivo e ao receber o avis...
#
#                              corpo_reclamacao_tokens
# 0  [nunca, mais, compro, nessa, loja, pelo, fato,...
# 1  [eu, a, loja, comprar, uma, luva, de, musculaç...
# 2  [estive, na, loja, da, marginal, tiete, no, di...
# 3  [comprei, 3, produtos, no, dia, 13.03, e, rece...
# 4  [comprei, um, tenis, esportivo, e, ao, receber...

# %% [markdown]
# ### 2.6 Remoção das StopWords

# %%
from nltk.corpus import stopwords
from string import punctuation
import re # Regex

#  Regex para encontrar pontuações dentro do texto
other_punctuation_reg = r'(\.{2,}|-+|—+|\|+)'

other_punctuation_finds = []

# Percorre a lista de reclamções e identica as pontuações
for text in reclamacoes.corpo_reclamacao_lower:
    # encontra as pontuações
    p = re.search(other_punctuation_reg, text)
    if p:
        other_punctuation_finds.append(p.group())

# Gera lista com stopwords em Português  
portuguese_stopswords = set(stopwords.words('portuguese') + list(punctuation) + other_punctuation_finds)

# Adicionando outras palavras na nossa lista de StopWords
portuguese_stopswords.add('é')

portuguese_stopswords
# Out:
# {'!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '..',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  'a',
#  'ao',
#  'aos',
#  'aquela',
#  'aquelas',
#  'aquele',
#  'aqueles',
#  'aquilo',
#  'as',
#  'até',
#  'com',
#  'como',
#  'da',
#  'das',
#  'de',
#  'dela',
#  'delas',
#  'dele',
#  'deles',
#  'depois',
#  'do',
#  'dos',
#  'e',
#  'ela',
#  'elas',
#  'ele',
#  'eles',
#  'em',
#  'entre',
#  'era',
#  'eram',
#  'essa',
#  'essas',
#  'esse',
#  'esses',
#  'esta',
#  'estamos',
#  'estas',
#  'estava',
#  'estavam',
#  'este',
#  'esteja',
#  'estejam',
#  'estejamos',
#  'estes',
#  'esteve',
#  'estive',
#  'estivemos',
#  'estiver',
#  'estivera',
#  'estiveram',
#  'estiverem',
#  'estivermos',
#  'estivesse',
#  'estivessem',
#  'estivéramos',
#  'estivéssemos',
#  'estou',
#  'está',
#  'estávamos',
#  'estão',
#  'eu',
#  'foi',
#  'fomos',
#  'for',
#  'fora',
#  'foram',
#  'forem',
#  'formos',
#  'fosse',
#  'fossem',
#  'fui',
#  'fôramos',
#  'fôssemos',
#  'haja',
#  'hajam',
#  'hajamos',
#  'havemos',
#  'hei',
#  'houve',
#  'houvemos',
#  'houver',
#  'houvera',
#  'houveram',
#  'houverei',
#  'houverem',
#  'houveremos',
#  'houveria',
#  'houveriam',
#  'houvermos',
#  'houverá',
#  'houverão',
#  'houveríamos',
#  'houvesse',
#  'houvessem',
#  'houvéramos',
#  'houvéssemos',
#  'há',
#  'hão',
#  'isso',
#  'isto',
#  'já',
#  'lhe',
#  'lhes',
#  'mais',
#  'mas',
#  'me',
#  'mesmo',
#  'meu',
#  'meus',
#  'minha',
#  'minhas',
#  'muito',
#  'na',
#  'nas',
#  'nem',
#  'no',
#  'nos',
#  'nossa',
#  'nossas',
#  'nosso',
#  'nossos',
#  'num',
#  'numa',
#  'não',
#  'nós',
#  'o',
#  'os',
#  'ou',
#  'para',
#  'pela',
#  'pelas',
#  'pelo',
#  'pelos',
#  'por',
#  'qual',
#  'quando',
#  'que',
#  'quem',
#  'se',
#  'seja',
#  'sejam',
#  'sejamos',
#  'sem',
#  'serei',
#  'seremos',
#  'seria',
#  'seriam',
#  'será',
#  'serão',
#  'seríamos',
#  'seu',
#  'seus',
#  'somos',
#  'sou',
#  'sua',
#  'suas',
#  'são',
#  'só',
#  'também',
#  'te',
#  'tem',
#  'temos',
#  'tenha',
#  'tenham',
#  'tenhamos',
#  'tenho',
#  'terei',
#  'teremos',
#  'teria',
#  'teriam',
#  'terá',
#  'terão',
#  'teríamos',
#  'teu',
#  'teus',
#  'teve',
#  'tinha',
#  'tinham',
#  'tive',
#  'tivemos',
#  'tiver',
#  'tivera',
#  'tiveram',
#  'tiverem',
#  'tivermos',
#  'tivesse',
#  'tivessem',
#  'tivéramos',
#  'tivéssemos',
#  'tu',
#  'tua',
#  'tuas',
#  'tém',
#  'tínhamos',
#  'um',
#  'uma',
#  'você',
#  'vocês',
#  'vos',
#  '{',
#  '|',
#  '}',
#  '~',
#  'à',
#  'às',
#  'é',
#  'éramos'}

# %% [markdown]
# O comando stopwords.words("portuguese") lista todas as stopwords em português;
#
# OU
#
# Para visualizar a lista de StopWords:
#
# Windows:
# C:\Users\SEU_USUARIO\AppData\Roaming\nltk_data\corpora\stopwords

# %%
# Verificando como era antes
print('Antes de remover as StopWords:')
reclamacoes.corpo_reclamacao_lower[0] # visualizando somente a primeira reclamação
# Out:
# Antes de remover as StopWords:
# 'nunca mais compro nessa loja pelo fato de que tive o pior atendimento de toda minha vida 23-03-2019.\nestávamos experimentando algumas chuteiras na loja da marginal tiete, e meu filho (13 anos)encontrou uma bola de futebol ali no chão, e começou a brincar, várias crianças nessa loja brincam com bolas e acessórios, quando estávamos saindo, meu filho chutou a bola próximo a uns gols que estavam expostos ali no setor, e um funcionário chamou a atenção dele na frente de todos ali, não entendi o motivo, e questionei para meu filho o que tinha acontecido e ele me disse, e nisso o mesmo funcionário veio me falar que tinha falado pro meu filho pra ele não chutar a bola ali naquele espaço, sendo que o meu filho só tinha rolado a bola pra aquele canto pois estávamos indo embora, nisso minha esposa questionou se ele estava chamando a atenção do meu filho teria que chamar a atenção de todas as crianças que estavam brincando ali, ai pra minha surpresa ele disse que meu filho tinha chutado a bola no gol e que tinha quebrado o gol, fiquei indignado e fui até a entrada da loja pedir para que chamassem o gerente e mais indignado ainda fiquei quando me aparece o rapaz que estava la no setor de chuteiras junto com o rapaz que chamou a atenção do meu filho dizendo que era o gerente(sei que não era o gerente da loja poderia ser o responsável do setor de chuteiras mais gerente da loja não era, porem ele disse que era o gerente)já me dizendo que o outro rapaz chamou a atenção do meu filho pois tinha uma placa dizendo que ele não poderia chutar bola no gol, porem naquele momento ele não tinha chutado bola nenhuma no gol, e sim para o canto do setor pois estávamos indo embora.\nos dois pontos que me indignaram a ponto de ir embora e deixar tudo que iriamos comprar foi que em uma loja tão grande e que sempre que fui, as crianças brincam e toda parte e nunca vi esse tipo de atitude, pois acredito que isso de as crianças poderem experimentar as coisas é uma coisa muito legal, e meu filho ser chamado a atenção eu de verdade não entendo, e em segundo lugar e não menos importante uma pessoa se passar por gerente de loja, por que sei que toda loja tem um gerente geral e querer justificar que tinha placa se esse nem era o problema.\nnunca mais compro em nenhuma loja, e quem eu puder dizer e convencer de não comprar eu farei.'

# %%
# Exemplo - Removendo StopWords da primeira reclamação
palavras_sem_stopwords = [token for token in reclamacoes['corpo_reclamacao_tokens'][0] if token not in portuguese_stopswords]
palavras_sem_stopwords
# Out:
# ['nunca',
#  'compro',
#  'nessa',
#  'loja',
#  'fato',
#  'pior',
#  'atendimento',
#  'toda',
#  'vida',
#  '23-03-2019.',
#  'experimentando',
#  'algumas',
#  'chuteiras',
#  'loja',
#  'marginal',
#  'tiete',
#  'filho',
#  '13',
#  'anos',
#  'encontrou',
#  'bola',
#  'futebol',
#  'ali',
#  'chão',
#  'começou',
#  'brincar',
#  'várias',
#  'crianças',
#  'nessa',
#  'loja',
#  'brincam',
#  'bolas',
#  'acessórios',
#  'saindo',
#  'filho',
#  'chutou',
#  'bola',
#  'próximo',
#  'uns',
#  'gols',
#  'expostos',
#  'ali',
#  'setor',
#  'funcionário',
#  'chamou',
#  'atenção',
#  'frente',
#  'todos',
#  'ali',
#  'entendi',
#  'motivo',
#  'questionei',
#  'filho',
#  'acontecido',
#  'disse',
#  'nisso',
#  'funcionário',
#  'veio',
#  'falar',
#  'falado',
#  'pro',
#  'filho',
#  'pra',
#  'chutar',
#  'bola',
#  'ali',
#  'naquele',
#  'espaço',
#  'sendo',
#  'filho',
#  'rolado',
#  'bola',
#  'pra',
#  'canto',
#  'pois',
#  'indo',
#  'embora',
#  'nisso',
#  'esposa',
#  'questionou',
#  'chamando',
#  'atenção',
#  'filho',
#  'chamar',
#  'atenção',
#  'todas',
#  'crianças',
#  'brincando',
#  'ali',
#  'ai',
#  'pra',
#  'surpresa',
#  'disse',
#  'filho',
#  'chutado',
#  'bola',
#  'gol',
#  'quebrado',
#  'gol',
#  'fiquei',
#  'indignado',
#  'entrada',
#  'loja',
#  'pedir',
#  'chamassem',
#  'gerente',
#  'indignado',
#  'ainda',
#  'fiquei',
#  'aparece',
#  'rapaz',
#  'la',
#  'setor',
#  'chuteiras',
#  'junto',
#  'rapaz',
#  'chamou',
#  'atenção',
#  'filho',
#  'dizendo',
#  'gerente',
#  'sei',
#  'gerente',
#  'loja',
#  'poderia',
#  'ser',
#  'responsável',
#  'setor',
#  'chuteiras',
#  'gerente',
#  'loja',
#  'porem',
#  'disse',
#  'gerente',
#  'dizendo',
#  'outro',
#  'rapaz',
#  'chamou',
#  'atenção',
#  'filho',
#  'pois',
#  'placa',
#  'dizendo',
#  'poderia',
#  'chutar',
#  'bola',
#  'gol',
#  'porem',
#  'naquele',
#  'momento',
#  'chutado',
#  'bola',
#  'nenhuma',
#  'gol',
#  'sim',
#  'canto',
#  'setor',
#  'pois',
#  'indo',
#  'embora',
#  'dois',
#  'pontos',
#  'indignaram',
#  'ponto',
#  'ir',
#  'embora',
#  'deixar',
#  'tudo',
#  'iriamos',
#  'comprar',
#  'loja',
#  'tão',
#  'grande',
#  'sempre',
#  'crianças',
#  'brincam',
#  'toda',
#  'parte',
#  'nunca',
#  'vi',
#  'tipo',
#  'atitude',
#  'pois',
#  'acredito',
#  'crianças',
#  'poderem',
#  'experimentar',
#  'coisas',
#  'coisa',
#  'legal',
#  'filho',
#  'ser',
#  'chamado',
#  'atenção',
#  'verdade',
#  'entendo',
#  'segundo',
#  'lugar',
#  'menos',
#  'importante',
#  'pessoa',
#  'passar',
#  'gerente',
#  'loja',
#  'sei',
#  'toda',
#  'loja',
#  'gerente',
#  'geral',
#  'querer',
#  'justificar',
#  'placa',
#  'problema',
#  'nunca',
#  'compro',
#  'nenhuma',
#  'loja',
#  'puder',
#  'dizer',
#  'convencer',
#  'comprar',
#  'farei']

# %%
# Função que remove as stopwords
def remove_stopwords(text, portuguese_stopswords):
    print('Tamanho do texto original {}'.format(len(word_tokenize(text))))
    # Remove as stopwords
    msgTokens_sem_stopwords = [token.lower() for token in word_tokenize(text) if token not in portuguese_stopswords]
    print('Tamanho do texto sem stopwords {}'.format(len(msgTokens_sem_stopwords)))
    print('Foram removidas {} stopwords'.format(len(word_tokenize(text))-len(msgTokens_sem_stopwords)))
    aux_msgTokens = " ".join(str(msg) for msg in msgTokens_sem_stopwords)
    return aux_msgTokens

# %%
# Removendo StopWords de todas as reclamações
   
# Percorre a lista de reclamações e cria uma coluna nova com o texto sem stopWords
for idx,text in enumerate(reclamacoes.corpo_reclamacao_lower):
    print('Removendo StopWords do index {}'.format(idx))
    reclamacoes.at[idx, 'corpo_reclamacao_semStopWords'] = remove_stopwords(text, portuguese_stopswords)
    print('---'*20)
# Out:
# Removendo StopWords do index 0
# Tamanho do texto original 467
# Tamanho do texto sem stopwords 222
# Foram removidas 245 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 1
# Tamanho do texto original 159
# Tamanho do texto sem stopwords 78
# Foram removidas 81 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 2
# Tamanho do texto original 160
# Tamanho do texto sem stopwords 84
# Foram removidas 76 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 3
# Tamanho do texto original 288
# Tamanho do texto sem stopwords 163
# Foram removidas 125 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 4
# Tamanho do texto original 174
# Tamanho do texto sem stopwords 85
# Foram removidas 89 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 5
# Tamanho do texto original 62
# Tamanho do texto sem stopwords 29
# Foram removidas 33 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 6
# Tamanho do texto original 59
# Tamanho do texto sem stopwords 29
# Foram removidas 30 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 7
# Tamanho do texto original 45
# Tamanho do texto sem stopwords 23
# Foram removidas 22 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 8
# Tamanho do texto original 220
# Tamanho do texto sem stopwords 108
# Foram removidas 112 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 9
# Tamanho do texto original 58
# Tamanho do texto sem stopwords 25
# Foram removidas 33 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 10
# Tamanho do texto original 40
# Tamanho do texto sem stopwords 23
# Foram removidas 17 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 11
# Tamanho do texto original 93
# Tamanho do texto sem stopwords 45
# Foram removidas 48 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 12
# Tamanho do texto original 73
# Tamanho do texto sem stopwords 43
# Foram removidas 30 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 13
# Tamanho do texto original 311
# Tamanho do texto sem stopwords 157
# Foram removidas 154 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 14
# Tamanho do texto original 302
# Tamanho do texto sem stopwords 156
# Foram removidas 146 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 15
# Tamanho do texto original 90
# Tamanho do texto sem stopwords 43
# Foram removidas 47 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 16
# Tamanho do texto original 53
# Tamanho do texto sem stopwords 29
# Foram removidas 24 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 17
# Tamanho do texto original 215
# Tamanho do texto sem stopwords 117
# Foram removidas 98 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 18
# Tamanho do texto original 107
# Tamanho do texto sem stopwords 56
# Foram removidas 51 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 19
# Tamanho do texto original 21
# Tamanho do texto sem stopwords 11
# Foram removidas 10 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 20
# Tamanho do texto original 53
# Tamanho do texto sem stopwords 23
# Foram removidas 30 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 21
# Tamanho do texto original 60
# Tamanho do texto sem stopwords 33
# Foram removidas 27 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 22
# Tamanho do texto original 160
# Tamanho do texto sem stopwords 77
# Foram removidas 83 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 23
# Tamanho do texto original 97
# Tamanho do texto sem stopwords 46
# Foram removidas 51 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 24
# Tamanho do texto original 128
# Tamanho do texto sem stopwords 54
# Foram removidas 74 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 25
# Tamanho do texto original 153
# Tamanho do texto sem stopwords 79
# Foram removidas 74 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 26
# Tamanho do texto original 97
# Tamanho do texto sem stopwords 45
# Foram removidas 52 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 27
# Tamanho do texto original 190
# Tamanho do texto sem stopwords 95
# Foram removidas 95 stopwords
# ------------------------------------------------------------

# %%
# Removendo StopWords de todas as Tags

# Percorre a lista de reclamações e cria uma coluna nova com o tags sem stop Words
reclamacoes.tags = reclamacoes.tags.astype(str)
for idx,text in enumerate(reclamacoes.tags):
    print('Removendo StopWords do index {}'.format(idx))
    reclamacoes.at[idx, 'Tags_semStopWords'] = remove_stopwords(text, portuguese_stopswords)
    print('---'*20)
# Out:
# Removendo StopWords do index 0
# Tamanho do texto original 2
# Tamanho do texto sem stopwords 2
# Foram removidas 0 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 1
# Tamanho do texto original 10
# Tamanho do texto sem stopwords 6
# Foram removidas 4 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 2
# Tamanho do texto original 9
# Tamanho do texto sem stopwords 6
# Foram removidas 3 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 3
# Tamanho do texto original 3
# Tamanho do texto sem stopwords 2
# Foram removidas 1 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 4
# Tamanho do texto original 8
# Tamanho do texto sem stopwords 6
# Foram removidas 2 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 5
# Tamanho do texto original 6
# Tamanho do texto sem stopwords 5
# Foram removidas 1 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 6
# Tamanho do texto original 2
# Tamanho do texto sem stopwords 2
# Foram removidas 0 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 7
# Tamanho do texto original 2
# Tamanho do texto sem stopwords 2
# Foram removidas 0 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 8
# Tamanho do texto original 10
# Tamanho do texto sem stopwords 7
# Foram removidas 3 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 9
# Tamanho do texto original 2
# Tamanho do texto sem stopwords 2
# Foram removidas 0 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 10
# Tamanho do texto original 13
# Tamanho do texto sem stopwords 7
# Foram removidas 6 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 11
# Tamanho do texto original 9
# Tamanho do texto sem stopwords 5
# Foram removidas 4 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 12
# Tamanho do texto original 9
# Tamanho do texto sem stopwords 5
# Foram removidas 4 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 13
# Tamanho do texto original 9
# Tamanho do texto sem stopwords 5
# Foram removidas 4 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 14
# Tamanho do texto original 7
# Tamanho do texto sem stopwords 4
# Foram removidas 3 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 15
# Tamanho do texto original 12
# Tamanho do texto sem stopwords 8
# Foram removidas 4 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 16
# Tamanho do texto original 9
# Tamanho do texto sem stopwords 5
# Foram removidas 4 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 17
# Tamanho do texto original 8
# Tamanho do texto sem stopwords 5
# Foram removidas 3 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 18
# Tamanho do texto original 11
# Tamanho do texto sem stopwords 6
# Foram removidas 5 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 19
# Tamanho do texto original 11
# Tamanho do texto sem stopwords 7
# Foram removidas 4 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 20
# Tamanho do texto original 9
# Tamanho do texto sem stopwords 5
# Foram removidas 4 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 21
# Tamanho do texto original 9
# Tamanho do texto sem stopwords 6
# Foram removidas 3 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 22
# Tamanho do texto original 10
# Tamanho do texto sem stopwords 8
# Foram removidas 2 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 23
# Tamanho do texto original 12
# Tamanho do texto sem stopwords 8
# Foram removidas 4 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 24
# Tamanho do texto original 1
# Tamanho do texto sem stopwords 1
# Foram removidas 0 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 25
# Tamanho do texto original 10
# Tamanho do texto sem stopwords 7
# Foram removidas 3 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 26
# Tamanho do texto original 12
# Tamanho do texto sem stopwords 8
# Foram removidas 4 stopwords
# ------------------------------------------------------------
# Removendo StopWords do index 27
# Tamanho do texto original 2
# Tamanho do texto sem stopwords 2
# Foram removidas 0 stopwords
# ------------------------------------------------------------

# %%
reclamacoes.head()
# Out:
#   empresa     data_reclamacao                      local  \
# 0  Loja A   23/03/19 às 18h33             Guarulhos - SP
# 1  Loja A   23/03/19 às 18h20               Taubaté - SP
# 2  Loja A   23/03/19 às 11h07       Franco da Rocha - SP
# 3  Loja A   23/03/19 às 10h57              Teresina - PI
# 4  Loja A   22/03/19 às 19h49   São Gonçalo do Pará - MG
#
#                                    titulo_reclamacao  \
# 0                                    Mau Atendimento
# 1  Produtos misturado na gondula e divergência na...
# 2                     Informaçao errada do vendedor.
# 3              Paguei por um produto fora do estoque
# 4  entregaram meu pedido a outra pessoa falando q...
#
#                                     corpo_reclamacao  \
# 0  Nunca mais compro nessa loja pelo fato de que ...
# 1  Eu a LOJA comprar uma luva de musculação, na q...
# 2  Estive na LOJA da Marginal Tiete no dia 15 de ...
# 3  Comprei 3 produtos no dia 13.03 e recebi email...
# 4  comprei um tenis esportivo e ao receber o avis...
#
#                                                 tags teve_resposta       data  \
# 0                                Calçados Esportivos             0 2019-03-23
# 1  Divergência de valores, Acessórios para Muscul...             0 2019-03-23
# 2  Produto errado, Raquetes e Tacos, Artigos Espo...             0 2019-03-23
# 3                            Acessórios de Vestuário             1 2019-03-23
# 4  Problemas na finalização da compra Tênis Calça...             0 2019-03-22
#
#     hora               cidade estado  \
# 0  18h33            Guarulhos     SP
# 1  18h20              Taubaté     SP
# 2  11h07      Franco da Rocha     SP
# 3  10h57             Teresina     PI
# 4  19h49  São Gonçalo do Pará     MG
#
#                               corpo_reclamacao_lower  \
# 0  nunca mais compro nessa loja pelo fato de que ...
# 1  eu a loja comprar uma luva de musculação, na q...
# 2  estive na loja da marginal tiete no dia 15 de ...
# 3  comprei 3 produtos no dia 13.03 e recebi email...
# 4  comprei um tenis esportivo e ao receber o avis...
#
#                              corpo_reclamacao_tokens  \
# 0  [nunca, mais, compro, nessa, loja, pelo, fato,...
# 1  [eu, a, loja, comprar, uma, luva, de, musculaç...
# 2  [estive, na, loja, da, marginal, tiete, no, di...
# 3  [comprei, 3, produtos, no, dia, 13.03, e, rece...
# 4  [comprei, um, tenis, esportivo, e, ao, receber...
#
#                        corpo_reclamacao_semStopWords  \
# 0  nunca compro nessa loja fato pior atendimento ...
# 1  loja comprar luva musculação gondula descrito ...
# 2  loja marginal tiete dia 15 março 2019 procura ...
# 3  comprei 3 produtos dia 13.03 recebi email conf...
# 4  comprei tenis esportivo receber aviso pedido c...
#
#                                    Tags_semStopWords
# 0                                calçados esportivos
# 1  divergência valores acessórios musculação arti...
# 2   produto errado raquetes tacos artigos esportivos
# 3                               acessórios vestuário
# 4  problemas finalização compra tênis calçados es...

# %% [markdown]
# ### 2.7 Normalização das palavras - Stemming e Lemmatization

# %% [markdown]
# Na língua portuguesa temos diferentes palavras flexionadas em gênero, número ou grau, além de alguns tempos verbais distintos.
#
# *Reclamar – Reclamação*
#
# *Problema – Problemão*
#
# A normalização de palavras pode ser entendida como a simplificação ou a radicalização de palavras.
#
# E existem duas técnicas mais conhecidas:
#
# *Stemming* - O processo de stemming consiste em reduzir a palavra à sua raiz, não levando em consideração a classe gramatical da palavra.
#
# *Lemmatization* - Consiste em aplicar técnicas para deflexionar as palavras (retira a conjugação verbal, caso seja um verbo, e altera os substantivos e os adjetivos para o singular masculino, de maneira a reduzir a palavra até sua forma de dicionário).
#
# Ex.:
#
# Menino: menino, menina, meninão
#
# Ficar: ficar, ficou, fique

# %%
nltk.download('rslp')
stemmer = nltk.stem.RSLPStemmer()

palavras = ['reclamação', 'reclamei', 'reclamando']

for w in palavras:
    print(stemmer.stem(w))
# Out:
# reclam
# reclam
# reclam
# [nltk_data] Downloading package rslp to
# [nltk_data]     C:\Users\Windows10\AppData\Roaming\nltk_data...
# [nltk_data]   Package rslp is already up-to-date!

# %% [markdown]
# ### Lemmatization

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
 
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Windows10\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# Exemplo de lematização, porém não existe uma biblioteca em português apenas em inglês no momento.

# %%
palavras = ['jumps', 'ladies', 'oranges']

for w in palavras:
    print(lemmatizer.lemmatize(w))

# plural removido
# Out:
# jump
# lady
# orange

# %% [markdown]
# ## 3.Análise dos dados

# %% [markdown]
# ### 3.1 Analise Empresas

# %%
# Gráficos
import matplotlib.pyplot as plt

# %matplotlib inline
# Quantidade de reclamcoes por empresa
empresa = reclamacoes.groupby("empresa")

plt.figure(figsize=(10,5))
empresa.size().sort_values(ascending=False).plot.bar()
plt.title("Quantidade de reclamacões por empresa")
plt.xticks(rotation=0)
plt.xlabel("Empresas")
plt.ylabel("Número de reclamações")
plt.show()

# %% [markdown]
# ### 3.2 Cidade e Estado

# %% [markdown]
# #### Cidades

# %%
# Vendo quando locais recebem vem as reclamações
cidades = reclamacoes.groupby("cidade")

plt.figure(figsize=(13,5))
cidades.size().sort_values(ascending=False).plot.bar()
plt.xticks(rotation=90)
plt.xlabel("Cidades")
plt.ylabel("Numero de reclamações")
plt.show()

# %% [markdown]
# #### Estados

# %%
# Vendo quando locais recebem vem as reclamações
estados = reclamacoes.groupby("estado")

plt.figure(figsize=(13,5))
estados.size().sort_values(ascending=False).plot.bar()
plt.xticks(rotation=90)
plt.xlabel("Estados")
plt.ylabel("Numero de reclamações")
plt.show()

# %% [markdown]
# ### 3.3 Frequencia de palavras de todas as reclamações

# %%
# NLTK
from nltk.probability import FreqDist

#função para ver as palavras mais frequente de todas as reclamações 

def freq_Words(text, number,titulo):
    words = word_tokenize(text)
    fdist = FreqDist(word for word in words)
    XY = fdist.items()
    XY = sorted(XY, key=lambda pair: pair[1], reverse=True)
    limit = number
    X = [x for (x,y) in XY[:limit]]
    Y = [y for (x,y) in XY[:limit]]
    nX = range(len(X))
    plt.figure(figsize=(13,5))
    plt.title("Tokens mais frequentes das {}".format(titulo))
    plt.plot(nX, Y, label='contagens dos tokens', color = "red")
    plt.xticks(nX, X, rotation='vertical')
    plt.xticks(rotation='60')
    plt.xlabel('Tokens')
    plt.ylabel('Contagens')
    plt.grid()
    plt.legend(loc='upper right', fontsize='small')
    #plt.tight_layout()
    plt.show()
    return fdist

# %%
#juntando todas as mensagens em um unico texto
lista_reclamacao = ' '.join(reclamacoes.corpo_reclamacao_semStopWords.tolist())
frequencia = freq_Words(lista_reclamacao,10,"reclamações")

# %% [markdown]
# ### 3.4 Frequencia de palavras de todas as tags

# %%
lista_tags = ' '.join(reclamacoes.Tags_semStopWords.tolist())
frequencia = freq_Words(lista_tags,10,"tags")

# %% [markdown]
# ### 3.5 Frequencia de Respostas

# %%
reclamacoes.teve_resposta = reclamacoes.teve_resposta.replace(0,"Não Respondido")
reclamacoes.teve_resposta = reclamacoes.teve_resposta.replace(1,"Respondido")      

respostas = reclamacoes.groupby("teve_resposta")
plt.figure(figsize=(10,5))
respostas.size().sort_values(ascending=False).plot.bar()
plt.title("Quantas reclamações foram respondidas?")
plt.xticks(rotation=0)
plt.xlabel("Respostas")
plt.ylabel("Numero de respostas")
plt.show()

# %% [markdown]
# ## 4. Nuvem de palavras

# %%
#Juntando todos os textos 

# Textos com StopWords
todas_reclamacoes = " ".join(review for review in reclamacoes.corpo_reclamacao_lower)

# Texto sem StopWords
todas_reclamacoes_semStopWords = " ".join(review for review in reclamacoes.corpo_reclamacao_semStopWords)

print ("Temos {} palavras juntando todas as reclamações.".format(len(todas_reclamacoes_semStopWords)))

print ("Temos {} palavras juntando todas as reclamações.".format(len(todas_reclamacoes)))
# Out:
# Temos 14354 palavras juntando todas as reclamações.
# Temos 20348 palavras juntando todas as reclamações.

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import numpy as np
from PIL import Image

# World Cloud
# Exemplo: World cloud de todas reclamações sem stopwords

# Gerando a wordcloud
plt.figure(figsize=(10,5))
wordcloud = WordCloud(background_color="white").generate(todas_reclamacoes_semStopWords)

# Mostrando nuvem de palavras com o matplotlib 
plt.title('WordCloud sem StopWords', fontsize=20)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# World Cloud
# Exemplo: World cloud de todos os textos (com stopwords)

# Gerando a wordcloud
plt.figure(figsize=(10,5))
wordcloud = WordCloud(background_color="white").generate(todas_reclamacoes)

#Mostrando nuvem de palavras com o matplotlib 
plt.title('WordCloud com StopWords', fontsize=20)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# Reparem na diferença na visualização.
#
# Na segunda, o resultado é muito menos util para um tomador de decisão que o primeiro.
#
# Por exemplo, "problema", "pedido", "gerente", podem ser palavras a levantar um alerta dentor da empresa.

# %%
# Exercicios: World cloud de uma unica empresa
todas_reclamacoes_empresa = " ".join(review for review in reclamacoes[reclamacoes.empresa == "Loja C"].corpo_reclamacao_lower)
     
plt.figure(figsize=(10,5))
wordcloud = WordCloud(background_color="white").generate(todas_reclamacoes_empresa)

#Mostrando nuvem de palavras com o matplotlib 
plt.title('WordCloud - Loja C', fontsize=20)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ### 4.1 Nuvem de palavras com Imagem

# %%
# Selecionar a imagem que será utilizada como template
# OBS: A imagem precisa estar na mesma pasta que o notebook!

# Para executar na sua maquina
py_mask = np.array(Image.open("girls.png")) 

# Para executar no Google Colab
# uploaded = files.upload()
# py_mask = np.array(Image.open(io.BytesIO(uploaded['pyladies.jpg'])))

# Cria a WordCloud passando a imagem selecionada acima como mascara
wc = WordCloud(background_color="white", max_words=10000, mask=py_mask)

wc.generate(todas_reclamacoes_semStopWords)

# Salva a imagem na sua maquina :)
wc.to_file("girls_wordcloud.png")


# plt.title('WordCloud - PyLadies', fontsize=20)
# plt.imshow(wc, interpolation='bilinear')
# plt.axis("off")
# plt.show()
plt.figure(figsize=[20,10])

image_colors = ImageColorGenerator(py_mask)
plt.imshow(wc.recolor(color_func=image_colors), interpolation='bilinear' )
plt.axis("off")
# Out:
# (-0.5, 568.5, 199.5, -0.5)

# %% [markdown]
# # BONUS
#
# # Um pouco de Deep Learning!

# %% [markdown]
# Vamos agora entrar no mundo do Deep Learning!
#
# Par isso vamos utilizar o Spacy, uma poderosa bilioteca de Processamento de Linguagem Natural e é focada em "entender" grandes quantidades de texto.
#
# Para instalar descomente a celula abaixo:
#
# <b>ATENÇÃO:</b> Para instalar o Spacy na sua maquina pessoal é necessario ter o Microsoft Visual C++ 14.0 (visual studio) instalado na maquina. No Colab ele já vem pré-instalado :)

# %%
# Se já não tiver instalado o spacy...

# !pip install spacy
# !python -m spacy download en
# !python -m spacy download pt
# !python -m spacy download pt_core_news_sm
# Out:
# Collecting spacy
#   Downloading https://files.pythonhosted.org/packages/69/d8/f3103202aeca6fb0d2dbdd3a4ab1a7b86e9ad1d3cf8b23fa46bd466d64ac/spacy-2.2.3-cp37-cp37m-win_amd64.whl (9.7MB)
# Collecting plac<1.2.0,>=0.9.6 (from spacy)
#   Downloading https://files.pythonhosted.org/packages/86/85/40b8f66c2dd8f4fd9f09d59b22720cffecf1331e788b8a0cab5bafb353d1/plac-1.1.3-py2.py3-none-any.whl
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Using cached https://files.pythonhosted.org/packages/4f/7b/d77bc9bb101e113884b2d70a118e7ec8dcc9846a35a0e10d47ca37acdcbf/murmurhash-1.0.2-cp37-cp37m-win_amd64.whl
# Requirement already satisfied: setuptools in c:\anaconda3\lib\site-packages (from spacy) (41.4.0)
# Collecting srsly<1.1.0,>=0.1.0 (from spacy)
#   Downloading https://files.pythonhosted.org/packages/03/a8/6ddcf5f8ed280e28a41cbef9b38ef8e4e005760c4eb1860bd239c9c1be99/srsly-1.0.1-cp37-cp37m-win_amd64.whl (179kB)
# Collecting blis<0.5.0,>=0.4.0 (from spacy)
#   Downloading https://files.pythonhosted.org/packages/d5/7e/1981d5389b75543f950026de40a9d346e2aec7e860b2800e54e65bd46c06/blis-0.4.1-cp37-cp37m-win_amd64.whl (5.0MB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Downloading https://files.pythonhosted.org/packages/84/d1/35eab0c8cc9fd9432becaf3e90144762b3201a45079e62c47a8ae8739763/cymem-2.0.3-cp37-cp37m-win_amd64.whl
# Collecting catalogue<1.1.0,>=0.0.7 (from spacy)
#   Downloading https://files.pythonhosted.org/packages/6c/f9/9a5658e2f56932e41eb264941f9a2cb7f3ce41a80cb36b2af6ab78e2f8af/catalogue-1.0.0-py2.py3-none-any.whl
# Collecting wasabi<1.1.0,>=0.4.0 (from spacy)
#   Downloading https://files.pythonhosted.org/packages/21/e1/e4e7b754e6be3a79c400eb766fb34924a6d278c43bb828f94233e0124a21/wasabi-0.6.0-py3-none-any.whl
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\windows10\appdata\roaming\python\python37\site-packages (from spacy) (2.22.0)
# Requirement already satisfied: numpy>=1.15.0 in c:\anaconda3\lib\site-packages (from spacy) (1.16.5)
# Collecting thinc<7.4.0,>=7.3.0 (from spacy)
#   Downloading https://files.pythonhosted.org/packages/9e/ed/7edded74724747f7dfc513f85b483db7828e4a1ed072c9625188dcb633a5/thinc-7.3.1-cp37-cp37m-win_amd64.whl (2.0MB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Downloading https://files.pythonhosted.org/packages/3c/5a/0d1b575ed40989d74fab25723083837c220246b25f3582917135cb32453f/preshed-3.0.2-cp37-cp37m-win_amd64.whl (105kB)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in c:\anaconda3\lib\site-packages (from catalogue<1.1.0,>=0.0.7->spacy) (0.23)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\windows10\appdata\roaming\python\python37\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2019.9.11)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\windows10\appdata\roaming\python\python37\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in c:\anaconda3\lib\site-packages (from thinc<7.4.0,>=7.3.0->spacy) (4.36.1)
# Requirement already satisfied: zipp>=0.5 in c:\anaconda3\lib\site-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy) (0.6.0)
# Requirement already satisfied: more-itertools in c:\anaconda3\lib\site-packages (from zipp>=0.5->importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy) (7.2.0)
# Installing collected packages: plac, murmurhash, srsly, blis, cymem, catalogue, wasabi, preshed, thinc, spacy
# Successfully installed blis-0.4.1 catalogue-1.0.0 cymem-2.0.3 murmurhash-1.0.2 plac-1.1.3 preshed-3.0.2 spacy-2.2.3 srsly-1.0.1 thinc-7.3.1 wasabi-0.6.0
# Collecting pt_core_news_sm==2.2.5 from https://github.com/explosion/spacy-models/releases/download/pt_core_news_sm-2.2.5/pt_core_news_sm-2.2.5.tar.gz#egg=pt_core_news_sm==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_sm-2.2.5/pt_core_news_sm-2.2.5.tar.gz (21.2MB)
# Requirement already satisfied: spacy>=2.2.2 in c:\anaconda3\lib\site-packages (from pt_core_news_sm==2.2.5) (2.2.3)
# Requirement already satisfied: thinc<7.4.0,>=7.3.0 in c:\anaconda3\lib\site-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (7.3.1)
# Requirement already satisfied: setuptools in c:\anaconda3\lib\site-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (41.4.0)
# Requirement already satisfied: numpy>=1.15.0 in c:\anaconda3\lib\site-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (1.16.5)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in c:\anaconda3\lib\site-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (1.1.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\windows10\appdata\roaming\python\python37\site-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (2.22.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\anaconda3\lib\site-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (2.0.3)
# Requirement already satisfied: srsly<1.1.0,>=0.1.0 in c:\anaconda3\lib\site-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (1.0.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\anaconda3\lib\site-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (3.0.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in c:\anaconda3\lib\site-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (0.6.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\anaconda3\lib\site-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (1.0.2)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in c:\anaconda3\lib\site-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (1.0.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in c:\anaconda3\lib\site-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (0.4.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in c:\anaconda3\lib\site-packages (from thinc<7.4.0,>=7.3.0->spacy>=2.2.2->pt_core_news_sm==2.2.5) (4.36.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->pt_core_news_sm==2.2.5) (1.24.3)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\windows10\appdata\roaming\python\python37\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->pt_core_news_sm==2.2.5) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->pt_core_news_sm==2.2.5) (2019.9.11)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\windows10\appdata\roaming\python\python37\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->pt_core_news_sm==2.2.5) (3.0.4)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in c:\anaconda3\lib\site-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->pt_core_news_sm==2.2.5) (0.23)
# Requirement already satisfied: zipp>=0.5 in c:\anaconda3\lib\site-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->pt_core_news_sm==2.2.5) (0.6.0)
# Requirement already satisfied: more-itertools in c:\anaconda3\lib\site-packages (from zipp>=0.5->importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->pt_core_news_sm==2.2.5) (7.2.0)
# Building wheels for collected packages: pt-core-news-sm
#   Building wheel for pt-core-news-sm (setup.py): started
#   Building wheel for pt-core-news-sm (setup.py): finished with status 'done'
#   Created wheel for pt-core-news-sm: filename=pt_core_news_sm-2.2.5-cp37-none-any.whl size=21186287 sha256=3bd3214d5e81fc4841b75dc75756afe27355e536435ba0f9970af8609787b6c5
#   Stored in directory: C:\Users\WINDOW~1\AppData\Local\Temp\pip-ephem-wheel-cache-m3710gna\wheels\ea\94\74\ec9be8418e9231b471be5dc7e1b45dd670019a376a6b5bc1c0
# Successfully built pt-core-news-sm
# Installing collected packages: pt-core-news-sm
# Successfully installed pt-core-news-sm-2.2.5
# [+] Download and installation successful
# You can now load the model via spacy.load('pt_core_news_sm')
# [x] Couldn't link model to 'pt'
# Creating a symlink in spacy/data failed. Make sure you have the required
# permissions and try re-running the command as admin, or use a virtualenv. You
# can still import the model as a module and call its load() method, or create the
# symlink manually.
# C:\Anaconda3\lib\site-packages\pt_core_news_sm -->
# C:\Anaconda3\lib\site-packages\spacy\data\pt
# [!] Download successful but linking failed
# Creating a shortcut link for 'pt' didn't work (maybe you don't have admin
# permissions?), but you can still load the model via its full package name: nlp =
# spacy.load('pt_core_news_sm')
# Vocˆ nao tem privil‚gios suficientes para realizar esta opera‡ao.
# Requirement already satisfied: pt_core_news_sm==2.2.5 from https://github.com/explosion/spacy-models/releases/download/pt_core_news_sm-2.2.5/pt_core_news_sm-2.2.5.tar.gz#egg=pt_core_news_sm==2.2.5 in c:\anaconda3\lib\site-packages (2.2.5)
# Requirement already satisfied: spacy>=2.2.2 in c:\anaconda3\lib\site-packages (from pt_core_news_sm==2.2.5) (2.2.3)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in c:\anaconda3\lib\site-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (0.4.1)
# Requirement already satisfied: srsly<1.1.0,>=0.1.0 in c:\anaconda3\lib\site-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (1.0.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\anaconda3\lib\site-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (2.0.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in c:\anaconda3\lib\site-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (0.6.0)
# Requirement already satisfied: setuptools in c:\anaconda3\lib\site-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (41.4.0)
# Requirement already satisfied: numpy>=1.15.0 in c:\anaconda3\lib\site-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (1.16.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in c:\anaconda3\lib\site-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (1.0.0)
# Requirement already satisfied: thinc<7.4.0,>=7.3.0 in c:\anaconda3\lib\site-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (7.3.1)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in c:\anaconda3\lib\site-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (1.1.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\anaconda3\lib\site-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (3.0.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\anaconda3\lib\site-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (1.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\windows10\appdata\roaming\python\python37\site-packages (from spacy>=2.2.2->pt_core_news_sm==2.2.5) (2.22.0)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in c:\anaconda3\lib\site-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->pt_core_news_sm==2.2.5) (0.23)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in c:\anaconda3\lib\site-packages (from thinc<7.4.0,>=7.3.0->spacy>=2.2.2->pt_core_news_sm==2.2.5) (4.36.1)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\windows10\appdata\roaming\python\python37\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->pt_core_news_sm==2.2.5) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->pt_core_news_sm==2.2.5) (2019.9.11)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->pt_core_news_sm==2.2.5) (1.24.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\windows10\appdata\roaming\python\python37\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->pt_core_news_sm==2.2.5) (3.0.4)
# Requirement already satisfied: zipp>=0.5 in c:\anaconda3\lib\site-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->pt_core_news_sm==2.2.5) (0.6.0)
# Requirement already satisfied: more-itertools in c:\anaconda3\lib\site-packages (from zipp>=0.5->importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->pt_core_news_sm==2.2.5) (7.2.0)
# [+] Download and installation successful
# You can now load the model via spacy.load('pt_core_news_sm')

# %% [markdown]
# ## 1. Primeiros passos com o Spacy

# %%
# Vamos usar o modelo pré-pronto que acabamos de baixar
import spacy

nlp = spacy.load('pt_core_news_sm') # Importando o modelo pré treinado de Deep Learning do Spacy em Português!

# Passando uma frase para o spacy
doc = nlp(u'Eai! Já ta sabendo tudo sobre NLP? A Camila conhece também, vou pedir pra ela me dar umas aulas')
# Obs: Repare no unicode na string...você deve usa-lo para que funcione corretamente.

# Tambem podemos Tokenizar o texto pelo Sapcy hehe
for token in doc:
    print(token.text)
# Out:
# Eai
# !
# Já
# ta
# sabendo
# tudo
# sobre
# NLP
# ?
# A
# Camila
# conhece
# também
# ,
# vou
# pedir
# pra
# ela
# me
# dar
# umas
# aulas

# %% [markdown]
# ## 2. Identificação de Entidades

# %% [markdown]
# A identificação de Entidade (em inglês Named Entity Recognition - NER) é a identificação de objetos/itens/coisas do mundo real, por exemplo, uma pessoa, um produto, um pais ou estado.
#
# Com o Spacy é possivel se treinar seu proprio algoritmo de NER.

# %%
# Entidades

doc = nlp(u"Apesar da Maria morar em São Paulo, ela me disse que seu sonho era morar em Nova York")

for ent in doc.ents:
    print('Texto: {}'.format(ent.text))
    print('Inicio: {}'.format(ent.start_char))
    print('Fim: {}'.format(ent.end_char))
    print('Entidade: {}'.format(ent.label_))
    print('----'*5)
# Out:
# Texto: Maria
# Inicio: 10
# Fim: 15
# Entidade: PER
# --------------------
# Texto: São Paulo
# Inicio: 25
# Fim: 34
# Entidade: LOC
# --------------------
# Texto: Nova York
# Inicio: 76
# Fim: 85
# Entidade: LOC
# --------------------

# %% [markdown]
# Lista com os tipos de Entidade suportados/Identificados pelo Spacy: https://spacy.io/api/annotation#named-entities

# %%
# Visualizando de uma forma mais bonita!

from spacy import displacy
from IPython.core.display import display, HTML

html = displacy.render(doc, style="ent")
display(HTML(html))
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">Apesar da
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Maria
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  morar em
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     São Paulo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , ela me disse que seu sonho era morar em
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nova York
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# </div>

# %%
# Sua vez!

# Exercicios: Aplique NER nas reclamações de uma empresa que você queira, quais entidades foram as mais retornadas?
reclamacoes_empresa_A = ' '.join(reclamacoes[reclamacoes.empresa == 'Loja A']['corpo_reclamacao'])
reclamacoes_empresa_A_spacy = nlp(reclamacoes_empresa_A)

html = displacy.render(reclamacoes_empresa_A_spacy, style="ent")
display(HTML(html))
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">Nunca mais compro nessa loja pelo fato de que tive o pior atendimento de toda minha vida 23-03-2019.</br>Estávamos experimentando algumas chuteiras na loja da
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Marginal Tiete
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , e meu filho (13 anos)encontrou uma bola de futebol ali no chão, e começou a brincar, várias crianças nessa loja brincam com bolas e acessórios, quando estávamos saindo, meu filho chutou a bola próximo a uns gols que estavam expostos ali no setor, e um funcionário chamou a atenção dele na frente de todos ali, não entendi o motivo, e questionei para meu filho o que tinha acontecido e ele me disse, e nisso o mesmo funcionário veio me falar que tinha falado pro meu filho pra ele não chutar a bola ali naquele espaço, sendo que o meu filho só tinha rolado a bola pra aquele canto pois estávamos indo embora, nisso minha esposa questionou se ele estava chamando a atenção do meu filho teria que chamar a atenção de todas as crianças que estavam brincando ali, ai pra minha surpresa ele disse que meu filho tinha chutado a bola no gol e que tinha quebrado o gol, fiquei indignado e fui até a entrada da loja pedir para que chamassem o gerente e mais indignado ainda fiquei quando me aparece o rapaz que estava la no setor de chuteiras junto com o rapaz que chamou a atenção do meu filho dizendo que era o gerente(sei que não era o gerente da loja poderia ser o responsável do setor de chuteiras mais gerente da loja não era, porem ele disse que era o gerente)já me dizendo que o outro rapaz chamou a atenção do meu filho pois tinha uma placa dizendo que ele não poderia chutar bola no gol, porem naquele momento ele não tinha chutado bola nenhuma no gol, e sim para o canto do setor pois estávamos indo embora.</br>Os dois pontos que me indignaram a ponto de ir embora e deixar tudo que iriamos comprar foi que em uma loja tão grande e que sempre que fui, as crianças brincam e toda parte e nunca vi esse tipo de atitude, pois acredito que isso de as crianças poderem experimentar as coisas é uma coisa muito legal, e meu filho ser chamado a atenção eu de verdade não entendo, e em segundo lugar e não menos importante uma pessoa se passar por gerente de loja, por que sei que toda loja tem um gerente geral e querer justificar que tinha placa se esse nem era o problema.</br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NUNCA MAIS COMPRO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  EM
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NENHUMA LOJA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     E QUEM EU PUDER DIZER E CONVENCER DE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  NÃO
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     COMPRAR EU FAREI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# . Eu a
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LOJA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  comprar uma luva de musculação, na qual a gondula está descrito melhor custo benefício, os produtos estão todos misturados na gondula sem qualquer identificação para qual seria o produto de 24.99, quando fui ao caixa com o vale troca e um produto de mesma gondula , o caixa informou que haveria
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     uma.diferenca
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  a pagar ,mas o produto bfoi retirado desta gondula com.varios tipos de luva de musculação, sendo está preta com polegar.
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tirei
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  uma foto e chamei um atendente no qual disse que a loja não tem culpa dos produtos estarem misturados pois a loja estava muito cheia, e não aceitou trocar o produto no qual havia comprado no dia anterior. A diferença era se 5.00 ,mas o que ocorre e sempre o desrespeito ao consumidor que e sempre enganado porque a loja nunca tem culpa de nada e principalmente em oferecer produtos com preços errados . Estive na
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LOJA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  da
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Marginal Tiete
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  no dia 15 de março de 2019, a procura de uma raquete de beach tenis, como é um esporte novo para mim, nao sabia ao certo qual raquete comprar, verifiquei a raquete
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PR830 Power RougeNoir
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  e
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PR890 Victory NoirRouge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  ambas da marca
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Artengo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  e perguntei para um vendedor pq ela era diferente das demais seu formato, o mesmo me informou que seria apenas o modelo e estilo de cada atleta, acabei comprando estes dois modelos, pois bem ao dar inicio as aulas de beach tenis, fui informado pelo professor que o modelo que comprei seria infantil, e nao adequada

# %% [markdown]
# ## 3. Part-of-speech tagging - POS Tagging
#
# ### Análise de classes gramaticais

# %% [markdown]
# Depois de tokenizar o texto é possivel identificar a classe gramatical de cada palavra/token (por exemplo, substantivo ou verbo)
#
# Essa tecnica é bastante usada na geração automatica de legendas ou até mesmo na tradução automatica, pois com ela podemos entender o contexto da frase e inferir qual a proxima palavra é mais propensa a ser a correta

# %%
doc = nlp(u'Apesar da Maria morar em São Paulo, ela me disse que seu sonho era morar em Nova York')

for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
# Out:
# Apesar Apesar ADV ADV|@ADVL> advmod Xxxxx True False
# da da ADP PRP|@A< mark xx True True
# Maria Maria PROPN PROP|F|S|@SUBJ> nsubj Xxxxx True False
# morar morar VERB <mv>|V|INF|@ICL-<ACC advcl xxxx True False
# em em ADP PRP|@<ADVL case xx True True
# São São PROPN PROPN obl Xxx True True
# Paulo Paulo PROPN PROPN flat:name Xxxxx True False
# , , PUNCT PU|@PU punct , False False
# ela ele PRON PERS|F|3S|NOM|@SUBJ> nsubj xxx True True
# me me PRON <refl>|PERS|M/F|1S|DAT|@DAT> iobj xx True True
# disse dizer VERB <mv>|V|PS|3S|IND|@FS-STA ROOT xxxx True False
# que que SCONJ KS|@SUB mark xxx True True
# seu seu DET <poss>|DET|M|S|@>N det xxx True True
# sonho sonhar NOUN <np-def>|N|M|S|@SUBJ> nsubj xxxx True False
# era ser VERB <mv>|V|IMPF|3S|IND|@FS-<ACC cop xxx True True
# morar morar VERB <mv>|V|INF|@ICL-<SC ccomp xxxx True False
# em em ADP PRP|@<ADVL case xx True True
# Nova Nova PROPN PROPN obl Xxxx True True
# York York PROPN PROPN flat:name Xxxx True False

# %%
html = displacy.render(doc, style="dep")
display(HTML(html))
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="pt" id="674b79ba28294a6e8c5bb1e5a3daa759-0" class="displacy" width="3200" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Apesar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">da</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">Maria</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">morar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">em</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">São</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">Paulo,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">ela</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">me</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">disse</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">que</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">seu</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">sonho</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">era</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">morar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">em</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">Nova</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">York</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-674b79ba28294a6e8c5bb1e5a3daa759-0-0" stroke-width="2px" d="M70,527.0 C70,2.0 1625.0,2.0 1625.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-674b79ba28294a6e8c5bb1e5a3daa759-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,529.0 L62,517.0 78,517.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-674b79ba28294a6e8c5bb1e5a3daa759-0-1" stroke-width="2px" d="M245,527.0 C245,352.0 555.0,352.0 555.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-674b79ba28294a6e8c5bb1e5a3daa759-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">mark</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,529.0 L237,517.0 253,517.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-674b79ba28294a6e8c5bb1e5a3daa759-0-2" stroke-width="2px" d="M420,527.0 C420,439.5 550.0,439.5 550.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-674b79ba28294a6e8c5bb1e5a3daa759-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,529.0 L412,517.0 428,517.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-674b79ba28294a6e8c5bb1e5a3daa759-0-3" stroke-width="2px" d="M70,527.0 C70,264.5 560.0,264.5 560.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-674b79ba28294a6e8c5bb1e5a3daa759-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M560.0,529.0 L568.0,517.0 552.0,517.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-674b79ba28294a6e8c5bb1e5a3daa759-0-4" stroke-width="2px" d="M770,527.0 C770,439.5 900.0,439.5 900.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-674b79ba28294a6e8c5bb1e5a3daa759-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,529.0 L762,517.0 778,517.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-674b79ba28294a6e8c5bb1e5a3daa759-0-5" stroke-width="2px" d="M595,527.0 C595,352.0 905.0,352.0 905.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-674b79ba28294a6e8c5bb1e5a3daa759

# %% [markdown]
# # Fim :)
